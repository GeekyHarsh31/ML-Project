# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 10
print(a)
print(type(a))
b = 10.0
print(b)
print(type(b))
c = "A"
print(c)
print(type(c))
d = True
print(type(d))
# Out:
# 10
# <class 'int'>
# 10.0
# <class 'float'>
# A
# <class 'str'>
# <class 'bool'>

# %%
List = [1,2,3,3,4,5,6]
print(List)
List[2] = 0
print(List)
# Out:
# [1, 2, 3, 3, 4, 5, 6]
# [1, 2, 0, 3, 4, 5, 6]

# %%
Tuple = (1,2,3,4,4,5,6,7)
print(Tuple)
# Out:
# (1, 2, 3, 4, 4, 5, 6, 7)

# %%
Dict  = {
    'Harsh' : "Jagwani",
    'Dict' : "datatype"
}
print(Dict)
Dict['Dict'] = "Dictionary"
print(Dict)
# Out:
# {'Harsh': 'Jagwani', 'Dict': 'datatype'}
# {'Harsh': 'Jagwani', 'Dict': 'Dictionary'}

# %%
def sum(a,b):
    return a+b

if __name__ == '__main__':
    a = int(input("Give the number"))
    b = int(input("Give the number"))  
    print(f"The sum of two numbers {a} & {b} is",sum(a,b))
# Out:
# The sum of two numbers 10 & 50 is 60

# %%
def EvenOdd(n):
    if n % 2 == 0:
        print(f"The number {n} is even")
    else: print(f"The number {n} is odd ")

if __name__ == '__main__':
    n = int(input("Give the number"))
    EvenOdd(n)
# Out:
# The number 10 is even

# %%
def GOT(a,b):
    if (a > b):
        print(f"{a} is greater")
    else : 
        print(f"{b} is greater")

if __name__ == '__main__':
    a = int(input("Give the number"))
    b = int(input("Give the number"))

    GOT(a,b)
# Out:
# 20 is greater
